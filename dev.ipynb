# %%
from backend.adapters.utils import get_audio_duration_from_s3, load_audio_from_s3
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from backend.adapters.utils import get_audio_duration_from_s3, load_audio_from_s3
#
# File ~/projects/deepaudio-lab/backend/adapters/utils.py:7
#       4 import librosa
#       5 import numpy as np
# ----> 7 from storage.client import s3_client
#      10 def get_class_mapping_from_s3_dataset(s3_prefix: str, split: str, bucket: str) -> dict[str, int]:
#      11     """Generate the DeepAudioX class mapping from a dataset stored in S3.
#      12
#      13     Lists virtual subdirectories under ``{s3_prefix}{split}/``
#    (...)     36         ValueError: If no classes are found under the given prefix.
#      37     """
#
# ModuleNotFoundError: No module named 'storage'

# %%
# Pick any key from the mapping to test with
sample_key = next(iter(file_to_class_mapping))
print("Key:", sample_key)

duration = get_audio_duration_from_s3(bucket="raw-audios", key=sample_key)
print(f"Duration: {duration:.2f}s")

# %%
y = load_audio_from_s3(bucket="raw-audios", key=sample_key, sample_rate=16_000)
print(f"Waveform shape: {y.shape}, dtype: {y.dtype}")
